# %% [markdown]
# ## Imports
#
# In this section we are going to import our libraries.

# %%
# !pip install google-api-python-client
# !pip install google-auth-httplib2
# !pip install google-auth-oauthlib
# !pip install schedule
# !pip install apscheduler
# Out:
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.7/dist-packages (1.12.8)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client) (3.0.1)
# Requirement already satisfied: google-auth>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client) (1.30.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client) (0.17.4)
# Requirement already satisfied: google-api-core<2dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client) (1.26.3)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client) (0.0.4)
# Requirement already satisfied: six<2dev,>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client) (1.15.0)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.16.0->google-api-python-client) (56.1.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.16.0->google-api-python-client) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.16.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.16.0->google-api-python-client) (4.2.2)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client) (1.53.0)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client) (3.12.4)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client) (2018.9)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client) (2.23.0)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client) (20.9)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth>=1.16.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client) (1.24.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<2dev,>=1.21.0->google-api-python-client) (2.4.7)
# Requirement already satisfied: google-auth-httplib2 in /usr/local/lib/python3.7/dist-packages (0.0.4)
# Requirement already satisfied: httplib2>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from google-auth-httplib2) (0.17.4)
# Requirement already satisfied: google-auth in /usr/local/lib/python3.7/dist-packages (from google-auth-httplib2) (1.30.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from google-auth-httplib2) (1.15.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth->google-auth-httplib2) (4.2.2)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth->google-auth-httplib2) (56.1.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth->google-auth-httplib2) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth->google-auth-httplib2) (0.2.8)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth->google-auth-httplib2) (0.4.8)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.7/dist-packages (0.4.4)
# Requirement already satisfied: google-auth>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib) (1.30.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib) (1.3.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.0.0->google-auth-oauthlib) (4.2.2)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.0.0->google-auth-oauthlib) (56.1.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.0.0->google-auth-oauthlib) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.0.0->google-auth-oauthlib) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.0.0->google-auth-oauthlib) (1.15.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.1.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.23.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth>=1.0.0->google-auth-oauthlib) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2020.12.5)
# Requirement already satisfied: schedule in /usr/local/lib/python3.7/dist-packages (1.1.0)
# Requirement already satisfied: apscheduler in /usr/local/lib/python3.7/dist-packages (3.7.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from apscheduler) (2018.9)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from apscheduler) (1.15.0)
# Requirement already satisfied: tzlocal~=2.0 in /usr/local/lib/python3.7/dist-packages (from apscheduler) (2.1)
# Requirement already satisfied: setuptools>=0.7 in /usr/local/lib/python3.7/dist-packages (from apscheduler) (56.1.0)

# %%
from googleapiclient.discovery import build
import os
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pip install plotly==4.11.0

# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns

import plotly.express as px
import plotly.offline as pyo
import plotly.figure_factory as ff
import plotly.graph_objects as go
# Out:
# Requirement already satisfied: plotly==4.11.0 in /usr/local/lib/python3.7/dist-packages (4.11.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.7/dist-packages (from plotly==4.11.0) (1.3.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly==4.11.0) (1.15.0)

# %% [markdown]
# ## Setup

# %%
API_KEY = "" # apply api key here

CHANNEL_ID = "UCNU_lfiiWBdtULKOw6X0Dig"

youtube = build('youtube', 'v3', developerKey=API_KEY)

hour_measure = 0

# %% [markdown]
# ## API Functions
#
# Problem:
# Using Youtube API (https://developers.google.com/youtube/v3/) scrapes channel videos with tags and stats.

# %%
# Function to get the channels stats
# It will also contain the upload playlist ID we can use to grab videos.
def get_channel_stats(youtube, channel_id):
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=channel_id
    )
    response = request.execute()
    
    return response['items']

# %%
# This will get us a list of videos from a playlist.
# Note a page of results has a max value of 50 so we will
# need to loop over our results with a pageToken

def get_video_list(youtube, upload_id):
    video_list = []
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=upload_id,
        maxResults=50
    )
    next_page = True
    while next_page:
        response = request.execute()
        data = response['items']

        for video in data:
            video_id = video['contentDetails']['videoId']
            if video_id not in video_list:
                video_list.append(video_id)

        # Do we have more pages?
        if 'nextPageToken' in response.keys():
            next_page = True
            request = youtube.playlistItems().list(
                part="snippet,contentDetails",
                playlistId=upload_id,
                pageToken=response['nextPageToken'],
                maxResults=50
            )
        else:
            next_page = False

    return video_list

# %%
# Once we have our video list we can pass it to this function to get details.
# Again we have a max of 50 at a time so we will use a for loop to break up our list. 
# check key exists 

def get_video_details(youtube, video_list):
    stats_list=[]

    # Can only get 50 videos at a time.
    for i in range(0, len(video_list), 50):
        request= youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=video_list[i:i+50]
        )

        data = request.execute()
        for video in data['items']:
            id = video['id']
            title=video['snippet']['title'] if 'title' in video['snippet'] else None
            published=video['snippet']['publishedAt'] if 'publishedAt' in video['snippet'] else None
            description=video['snippet']['description'] if 'description' in video['snippet'] else None
            tag_count= len(video['snippet']['tags'] if 'tags' in video['snippet'] else [])
            tags = video['snippet']['tags'] if 'tags' in video['snippet'] else None
            statistics = video['statistics'] if 'statistics' in video else None
            view_count=video['statistics'].get('viewCount',0)
            like_count=video['statistics'].get('likeCount',0)
            dislike_count=video['statistics'].get('dislikeCount',0)
            comment_count=video['statistics'].get('commentCount',0)
            stats_dict=dict(id = id, title=title, description=description, published=published, tag_count=tag_count, tags = tags, statistics = statistics, view_count=view_count, like_count=like_count, dislike_count=dislike_count, comment_count=comment_count)
            stats_list.append(stats_dict)

    return stats_list

# %% [markdown]
# ### Create our channel stats

# %%
channel_stats = get_channel_stats(youtube, CHANNEL_ID)

# %% [markdown]
# ### Find our upload playlist ( will contain all video uploads )

# %%
upload_id = channel_stats[0]['contentDetails']['relatedPlaylists']['uploads']

# %% [markdown]
# ### Get our Video List

# %%
video_list = get_video_list(youtube, upload_id)

# %%
len(video_list)
# Out:
# 1044

# %%
# splitted_video_list = video_list[0:10]

# %% [markdown]
# ### Get our Video Details
#
# Finally we will get all of our videos details returned in a dictionary.

# %%
video_data = get_video_details(youtube, video_list)

# %% [markdown]
# ## Creating Pandas DF
# In this section we will covert our data to pandas dataframe and start visualizing. I have also created a CSV of data in the cell below if you don't want to do the API calls yourself.

# %%
df_tags_stats = pd.DataFrame(video_data)
df_tags_stats['title_length'] = df_tags_stats['title'].str.len()
df_tags_stats["view_count"] = pd.to_numeric(df_tags_stats["view_count"])
df_tags_stats["like_count"] = pd.to_numeric(df_tags_stats["like_count"])
df_tags_stats["dislike_count"] = pd.to_numeric(df_tags_stats["dislike_count"])
df_tags_stats["comment_count"] = pd.to_numeric(df_tags_stats["comment_count"])
# reaction used later add up likes + dislikes + comments
df_tags_stats["reactions"] = df_tags_stats["like_count"] + df_tags_stats["dislike_count"] + df_tags_stats["comment_count"]
df_tags_stats.head()
# Out:
#             id  ... reactions
# 0  lxSBH6p0v1U  ...        26
# 1  cB3ycWAaznA  ...       116
# 2  bTMVj6DPdnY  ...        67
# 3  Pp90jv0ylAM  ...       632
# 4  G9bJcNYv3fQ  ...       528
#
# [5 rows x 13 columns]

# %%
df_tags_stats_1 = df_tags_stats

# %%
df_tags_stats_1.head(3)
# Out:
#             id  ... reactions
# 0  lxSBH6p0v1U  ...        26
# 1  cB3ycWAaznA  ...       116
# 2  bTMVj6DPdnY  ...        67
#
# [3 rows x 13 columns]

# %% [markdown]
# # Checking video stat after some interval
# Problem:
#
# Need to track changes of video stats every N minutes to see how videos are performing. Please pick the interval to scan stats which, according to you, is efficient and smart. You can hardcode channel ID in code, that’s not important.
#
# ###interval = 30 min

# %%
def video_updating_stats(youtube, video_list):

    stats_list=[]

    # Can only get 50 videos at a time.
    for i in range(0, len(video_list), 50):
        request= youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=video_list[i:i+50]
        )

        data = request.execute()
        for video in data['items']:
            id = video['id']
            title=video['snippet']['title'] if 'title' in video['snippet'] else None
            published=video['snippet']['publishedAt'] if 'publishedAt' in video['snippet'] else None
            description=video['snippet']['description'] if 'description' in video['snippet'] else None
            tag_count= len(video['snippet']['tags'] if 'tags' in video['snippet'] else [])
            tags = video['snippet']['tags'] if 'tags' in video['snippet'] else None
            statistics = video['statistics'] if 'statistics' in video else None
            view_count=video['statistics'].get('viewCount',0)
            like_count=video['statistics'].get('likeCount',0)
            dislike_count=video['statistics'].get('dislikeCount',0)
            comment_count=video['statistics'].get('commentCount',0)
            stats_dict=dict(id = id, title=title, description=description, published=published, tag_count=tag_count, tags = tags, statistics = statistics, view_count=view_count, like_count=like_count, dislike_count=dislike_count, comment_count=comment_count)
            stats_list.append(stats_dict)

    return stats_list

# %%
def dict_to_series(video_list):

    stats_list = video_updating_stats(youtube, video_list)

    global df_tags_stats_1

    df_interval = pd.DataFrame(stats_list)
    df_interval["view_count"] = pd.to_numeric(df_interval["view_count"])
    df_interval["like_count"] = pd.to_numeric(df_interval["like_count"])
    df_interval["dislike_count"] = pd.to_numeric(df_interval["dislike_count"])
    df_interval["comment_count"] = pd.to_numeric(df_interval["comment_count"])
    # reaction used later add up likes + dislikes + comments
    df_interval["reactions"] = df_interval["like_count"] + df_interval["dislike_count"] + df_interval["comment_count"]
    df_tags_stats_1['view_count'] = np.where(df_tags_stats_1['id'] == df_interval['id'], df_interval["view_count"], df_tags_stats_1['view_count'])
    df_tags_stats_1['like_count'] = np.where(df_tags_stats_1['id'] == df_interval['id'], df_interval["like_count"], df_tags_stats_1['like_count'])
    df_tags_stats_1['dislike_count'] = np.where(df_tags_stats_1['id'] == df_interval['id'], df_interval["dislike_count"], df_tags_stats_1['dislike_count'])
    df_tags_stats_1['comment_count'] = np.where(df_tags_stats_1['id'] == df_interval['id'], df_interval["comment_count"], df_tags_stats_1['comment_count'])
    
    global hour_measure
    if hour_measure < 61:
        df_tags_stats_1['one_hour_views'] = df_tags_stats_1['view_count']
    
    hour_measure += 30;

    
    all_videos_performance_percentage = df_tags_stats_1['one_hour_views'].median()
    df_tags_stats_1['performance_percentage'] = np.where(df_tags_stats_1['id'] == df_interval['id'], df_tags_stats_1["one_hour_views"] / all_videos_performance_percentage, 0)
   
    conditions = [(df_tags_stats_1['performance_percentage'] < 0.3),
                  (df_tags_stats_1['performance_percentage'] >= 0.3) & (df_tags_stats_1['performance_percentage'] < 0.5), 
                  (df_tags_stats_1['performance_percentage'] >= 0.5) & (df_tags_stats_1['performance_percentage'] < 0.7), 
                  (df_tags_stats_1['performance_percentage'] >= 0.7) & (df_tags_stats_1['performance_percentage'] < 0.9), 
                  (df_tags_stats_1['performance_percentage'] >= 0.9)]

    choices = ['Bad','Below Average','Average','Good', 'Very Good']
    df_tags_stats_1['performance'] = np.select(conditions, choices, default=np.nan)

    

    return df_interval

# %% [markdown]
# #Background Task Scheduler

# %%
import time
import atexit

from apscheduler.schedulers.background import BackgroundScheduler

list_blank = []
df_new = pd.DataFrame(list_blank)
 
def job():
    global df_new
    df_new = dict_to_series(video_list)
    df_new['time'] = time.time()
    df1 = df_new.groupby(['id'])
    # df1.plot()
    # df_new.set_index("time", inplace = True)

 
 
scheduler = BackgroundScheduler()
scheduler.add_job(func=job, trigger="interval", minutes=30)
scheduler.start()

# %% [markdown]
# ## Shutdown the scheduler when you want / as you wish

# %%
scheduler.shutdown()

# %%
df_new.head(5)
# Out:
#             id  ...          time
# 0  lxSBH6p0v1U  ...  1.622641e+09
# 1  cB3ycWAaznA  ...  1.622641e+09
# 2  bTMVj6DPdnY  ...  1.622641e+09
# 3  Pp90jv0ylAM  ...  1.622641e+09
# 4  G9bJcNYv3fQ  ...  1.622641e+09
#
# [5 rows x 13 columns]

# %%
df_new.shape
# Out:
# (1044, 13)

# %%
df_tags_stats_1.head(5)
# Out:
#             id  ... performance
# 0  lxSBH6p0v1U  ...         Bad
# 1  cB3ycWAaznA  ...         Bad
# 2  bTMVj6DPdnY  ...         Bad
# 3  Pp90jv0ylAM  ...   Very Good
# 4  G9bJcNYv3fQ  ...   Very Good
#
# [5 rows x 16 columns]

# %%
df_tags_stats_1.to_csv("youtubeData.csv")

# %%
df_tags_stats_1.shape
# Out:
# (1044, 16)

# %%
df1 = df_new[['id','title', 'view_count','like_count','dislike_count','comment_count', 'reactions', 'time']]
df1 = df1.groupby(['id'])
df1.head().style
# Out:
# <style  type="text/css" >
# </style><table id="T_33887f62_c3a7_11eb_9196_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >title</th>        <th class="col_heading level0 col2" >view_count</th>        <th class="col_heading level0 col3" >like_count</th>        <th class="col_heading level0 col4" >dislike_count</th>        <th class="col_heading level0 col5" >comment_count</th>        <th class="col_heading level0 col6" >reactions</th>        <th class="col_heading level0 col7" >time</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_33887f62_c3a7_11eb_9196_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row0_col0" class="data row0 col0" >lxSBH6p0v1U</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row0_col1" class="data row0 col1" >Tutorial 2-Linear Algebra For ML-How To Add 2 Vectors</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row0_col2" class="data row0 col2" >264</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row0_col3" class="data row0 col3" >25</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row0_col4" class="data row0 col4" >3</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row0_col5" class="data row0 col5" >4</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row0_col6" class="data row0 col6" >32</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row0_col7" class="data row0 col7" >1622640780.118958</td>
#             </tr>
#             <tr>
#                         <th id="T_33887f62_c3a7_11eb_9196_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row1_col0" class="data row1 col0" >cB3ycWAaznA</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row1_col1" class="data row1 col1" >Linear Algebra-What is Scalar and Vectors And Its Practical Applications In Machine Learning? ⭐⭐⭐⭐⭐⭐</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row1_col2" class="data row1 col2" >1632</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row1_col3" class="data row1 col3" >96</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row1_col4" class="data row1 col4" >3</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row1_col5" class="data row1 col5" >18</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row1_col6" class="data row1 col6" >117</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row1_col7" class="data row1 col7" >1622640780.118958</td>
#             </tr>
#             <tr>
#                         <th id="T_33887f62_c3a7_11eb_9196_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row2_col0" class="data row2 col0" >bTMVj6DPdnY</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row2_col1" class="data row2 col1" >Success Story Of Ameya- Transition To Devops In Vodafone  At GermanyFt:iNeuron</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row2_col2" class="data row2 col2" >1748</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row2_col3" class="data row2 col3" >56</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row2_col4" class="data row2 col4" >1</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row2_col5" class="data row2 col5" >11</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row2_col6" class="data row2 col6" >68</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row2_col7" class="data row2 col7" >1622640780.118958</td>
#             </tr>
#             <tr>
#                         <th id="T_33887f62_c3a7_11eb_9196_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row3_col0" class="data row3 col0" >Pp90jv0ylAM</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row3_col1" class="data row3 col1" >Explaining An End To End Machine Learning Project To A Interviewer</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row3_col2" class="data row3 col2" >12914</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row3_col3" class="data row3 col3" >607</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row3_col4" class="data row3 col4" >7</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row3_col5" class="data row3 col5" >25</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row3_col6" class="data row3 col6" >639</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row3_col7" class="data row3 col7" >1622640780.118958</td>
#             </tr>
#             <tr>
#                         <th id="T_33887f62_c3a7_11eb_9196_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row4_col0" class="data row4 col0" >G9bJcNYv3fQ</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row4_col1" class="data row4 col1" >Explaining An End To End Data Analyst/Business Analytics Projects</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row4_col2" class="data row4 col2" >11220</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row4_col3" class="data row4 col3" >501</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row4_col4" class="data row4 col4" >10</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row4_col5" class="data row4 col5" >20</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row4_col6" class="data row4 col6" >531</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row4_col7" class="data row4 col7" >1622640780.118958</td>
#             </tr>
#             <tr>
#                         <th id="T_33887f62_c3a7_11eb_9196_0242ac1c0002level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row5_col0" class="data row5 col0" >sMpi7nfrwz8</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row5_col1" class="data row5 col1" >Success Story Of Dhruv- Transition As Data Scientist In McKinsey & Company</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row5_col2" class="data row5 col2" >9748</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row5_col3" class="data row5 col3" >283</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row5_col4" class="data row5 col4" >2</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row5_col5" class="data row5 col5" >19</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row5_col6" class="data row5 col6" >304</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row5_col7" class="data row5 col7" >1622640780.118958</td>
#             </tr>
#             <tr>
#                         <th id="T_33887f62_c3a7_11eb_9196_0242ac1c0002level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row6_col0" class="data row6 col0" >eXZEFrKGaxA</td>
#                         <td id="T_33887f62_c3a7_11eb_9196_0242ac1c0002row6_col1" class="data row6 col1" >Permutation And Combination Easily Explained

# %% [markdown]
# #Maximum number of Channel_list
#
# Problem:
#
# Bonus points for:
#
# i) pseudo algorithm for fetching as many youtube channels as possible.

# %%
# Function to get the maximum number of channels
# It will also contain the upload playlist ID we can use to grab videos.
def get_channel_lists(youtube):
    channel_list = []
    request = youtube.search().list(
        part="snippet",
        channelType="any",
        maxResults=50,
        order="date",
        publishedAfter="2021-05-26T05:40:00+00:00",
        publishedBefore="2021-05-27T05:40:00+00:00",
        type="channel"
    )

    next_page = True

    while next_page:
        response = request.execute()
        channels = response['items']

        for channel in channels:
            channel_id = channel['id']['channelId']
            if channel_id not in channel_list:
                channel_list.append(channel_id)

        # Do we have more pages?
        if 'nextPageToken' in response.keys():
            next_page = True
            request = youtube.search().list(
                part="snippet",
                channelType="any",
                maxResults=50,
                order="date",
                pageToken=response['nextPageToken'],
                publishedAfter="2021-05-26T05:40:00+00:00",
                publishedBefore="2021-05-27T05:40:00+00:00",
                type="channel"
            )
        else:
            next_page = False
    
    return channel_list

# %%
channel_list = get_channel_lists(youtube)
print(len(channel_list))
# Out:
# 589

# %% [markdown]
# #Filter videos by Tag

# %%
def video_details_by_tag(youtube, tag):
    video_details_list = []
    request = youtube.search().list(
        part="snippet",
        maxResults=50,
        order="date",
        publishedAfter="2021-05-26T05:40:00+00:00",
        publishedBefore="2021-05-27T05:40:00+00:00",
        q=tag,
        type="video",
        videoType="any",
        prettyPrint=True,
    )

    next_page = True

    while next_page:
        response = request.execute()
        video_data = response['items']

        for video in video_data:
            video_data_dict = {
                "id" : video['id']['videoId'],
                "url" : f"https://www.youtube.com/watch?v={ video['id']['videoId'] }",
                "thumbnails" : video['snippet']['thumbnails']['high']['url'],
                "title" : video['snippet']['title'],
            }

            if video_data_dict not in video_details_list:
                video_details_list.append(video_data_dict)

        # Do we have more pages?
        if 'nextPageToken' in response.keys():
            next_page = True
            request = youtube.search().list(
                part="snippet",
                maxResults=50,
                order="date",
                publishedAfter="2021-05-26T05:40:00+00:00",
                publishedBefore="2021-05-27T05:40:00+00:00",
                q=tag,
                pageToken=response['nextPageToken'],
                type="video",
                videoType="any",
                prettyPrint=True,
            )
        else:
            next_page = False
    
    return video_details_list

# %%
video_details_list = video_details_by_tag(youtube, "django")
print(len(video_details_list))
# Out:
# 79

# %%
video_details_list
# Out:
# [{'id': 'RuxrnDpahxw',
#   'thumbnails': 'https://i.ytimg.com/vi/RuxrnDpahxw/hqdefault.jpg',
#   'title': 'How To Download Free E-commerce Templates | E-commerce Website Using Django | Django | Hindi 🤨',
#   'url': 'https://www.youtube.com/watch?v=RuxrnDpahxw'},
#  {'id': 'YvzUN6eMEKg',
#   'thumbnails': 'https://i.ytimg.com/vi/YvzUN6eMEKg/hqdefault.jpg',
#   'title': '23.기초부터 제작하는 파이썬 장고(Python Django) 프로젝트 -   Django + 디자인 프레임워크 적용 화면 꾸미기 2',
#   'url': 'https://www.youtube.com/watch?v=YvzUN6eMEKg'},
#  {'id': 'Q-CLW_mzk44',
#   'thumbnails': 'https://i.ytimg.com/vi/Q-CLW_mzk44/hqdefault.jpg',
#   'title': '🔴 Créer un blog complet avec django de A Z  #05 Bien comprendre la structure d&#39;un projet django',
#   'url': 'https://www.youtube.com/watch?v=Q-CLW_mzk44'},
#  {'id': 'Qk9zcpYKLVg',
#   'thumbnails': 'https://i.ytimg.com/vi/Qk9zcpYKLVg/hqdefault.jpg',
#   'title': 'créer votre Netflix avec django et bootstrap',
#   'url': 'https://www.youtube.com/watch?v=Qk9zcpYKLVg'},
#  {'id': 'zVNdh8ZBmPc',
#   'thumbnails': 'https://i.ytimg.com/vi/zVNdh8ZBmPc/hqdefault.jpg',
#   'title': 'Learning Management System Project in Django with Source Code | Fee Django Projects with Source Code',
#   'url': 'https://www.youtube.com/watch?v=zVNdh8ZBmPc'},
#  {'id': 'pKNAQ8pWGgo',
#   'thumbnails': 'https://i.ytimg.com/vi/pKNAQ8pWGgo/hqdefault.jpg',
#   'title': 'Instalación de Django en laragon',
#   'url': 'https://www.youtube.com/watch?v=pKNAQ8pWGgo'},
#  {'id': 'gDuPHxJfD9I',
#   'thumbnails': 'https://i.ytimg.com/vi/gDuPHxJfD9I/hqdefault.jpg',
#   'title': 'Django Rest Framework (Excepciones)',
#   'url': 'https://www.youtube.com/watch?v=gDuPHxJfD9I'},
#  {'id': 'qwG4ngamBK8',
#   'thumbnails': 'https://i.ytimg.com/vi/qwG4ngamBK8/hqdefault.jpg',
#   'title': 'SLOW DOWN (THE BEATLES) / THE PALM SPRINGS DJANGO and KO$HY Birthday Live at GREASE',
#   'url': 'https://www.youtube.com/watch?v=qwG4ngamBK8'},
#  {'id': 'jK4wX_ptk24',
#   'thumbnails': 'https://i.ytimg.com/vi/jK4wX_ptk24/hqdefault.jpg',
#   'title': 'Super filme de Django 2021 com muito tiro e ação',
#   'url': 'https://www.youtube.com/watch?v=jK4wX_ptk24'},
#  {'id': 'wOuZvHPeBG0',
#   'thumbnails': 'https://i.ytimg.com/vi/wOuZvHPeBG0/hqdefault_live.jpg',
#   'title': 'API + Django REST Framework',
#   'url': 'https://www.youtube.com/watch?v=wOuZvHPeBG0'},
#  {'id': 'f-A0imZcCCc',
#   'thumbnails': 'https://i.ytimg.com/vi/f-A0imZcCCc/hqdefault.jpg',
#   'title': '22.기초부터 제작하는 파이썬 장고(Python Django) 프로젝트 -   Django + BootStrap 등 디자인 프레임워크 적용 화면 꾸미기1',
#   'url': 'https://www.youtube.com/watch?v=f-A0imZcCCc'},
#  {'id': 'Ii0jU-dBixE',
#   'thumbnails': 'https://i.ytimg.com/vi/Ii0jU-dBixE/hqdefault.jpg',
#   'title': 'SUMbuilders Django TodoApp part2',
#   'url': 'https://www.youtube.com/watch?v=Ii0jU-dBixE'},
#  {'id': 'INDe9YvSZRI',
#   'thumbnails': 'https://i.ytimg.com/vi/INDe9YvSZRI/hqdefault.jpg',
#   'title': 'SUMbuilders Django TodoApp part1',
#   'url': 'https://www.youtube.com/watch?v=INDe9YvSZRI'},
#  {'id': 'N4LU48VJ7a8',
#   'thumbnails': 'https://i.ytimg.com/vi/N4LU48VJ7a8/hqdefault.jpg',
#   'title': 'Django 2',
#   'url': 'https://www.youtube.com/watch?v=N4LU48VJ7a8'},
#  {'id': 'xEaateGN35Y',
#   'thumbnails': 'https://i.ytimg.com/vi/xEaateGN35Y/hqdefault.jpg',
#   'title': 'Django 3',
#   'url': 'https://www.youtube.com/watch?v=xEaateGN35Y'},
#  {'id': 'dZU6cSMdpJE',
#   'thumbnails': 'https://i.ytimg.com/vi/dZU6cSMdpJE/hqdefault.jpg',
#   'title': 'DevOps &amp; SysAdmins: How to integrate PHP forum system with new Django website?',
#   'url': 'https://www.youtube.com/watch?v=dZU6cSMdpJE'},
#  {'id': '_Xf9gQ7n8Tc',
#   'thumbnails': 'https://i.ytimg.com/vi/_Xf9gQ7n8Tc/hqdefault.jpg',
#   'title': 'Website (with Django, Python, JS, HTML)',
#   'url': 'https://www.youtube.com/watch?v=_Xf9gQ7n8Tc'},
#  {'id': '9LCkKmdRj98',
#   'thumbnails': 'https://i.ytimg.com/vi/9LCkKmdRj98/hqdefault.jpg',
#   'title': 'Django Unchained Tattoo Speedrawing',
#   'url': 'https://www.youtube.com/watch?v=9LCkKmdRj98'},
#  {'id': 'fALAX6Il9mw',
#   'thumbnails': 'https://i.ytimg.com/vi/fALAX6Il9mw/hqdefault.jpg',
#   'title': 'DragonPy Meetup May 2021 Alan Una Larisa: Django-mockingbird - Unit testing Django applications',
#   'url': 'https://www.youtube.com/watch?v=fALAX6Il9mw'},
#  {'id': 'OvPdZe2mkco',
#   'thumbnails': 'https://i.ytimg.com/vi/OvPdZe2mkco/hqdefault.jpg',
#   'title': 'Introducción a Framewors Django y React',
#   'url': 'https://www.youtube.com/watch?v=OvPdZe2mkco'},
#  {'id': 'OnIggAeXmn0',
#   'thumbnails': 'https://i.ytimg.com/vi/OnIggAeXmn0/hqdefault.jpg',
#   'title': '10,000 Mil Dólares Para Django',
#   'url': 'https://www.youtube.com/watch?v=OnIggAeXmn0'},
#  {'id': 'h4EtcgqOkUI',
#   'thumbnails': 'https://i.ytimg.com/vi/h4EtcgqOkUI/hqdefault.jpg',
#   'title': 'DevOps &amp; SysAdmins: Django installation on Ubuntu + Apache2 +mod_python (2 Solutions!!)',
#   'url': 'https://www.youtube.com/watch?v=h4EtcgqOkUI'},
#  {'id': 'x1kKYDbvPUs',
#   'thumbnails': 'https://i.ytimg.com/vi/x1kKYDbvPUs/hqdefault.jpg',
#   'title': 'جانجو 456 عرض الطلب عرض سلة المشتريات بايثون python django جانجو',
#   'url': 'https://www.youtube.com/watch?v=x1kKYDbvPUs'},
#  {'id': 'y6kRqMgeKHI',
#   'thumbnails': 'https://i.ytimg.com/vi/y6kRqMgeKHI/hqdefault.jpg',
#   'title': 'manal - django (lyrics _ كلمات ) album 360',
#   'url': 'https://www.youtube.com/watch?v=y6kRqMgeKHI'},
#  {'id': 'DAjyGi19mQw',
#   'thumbnails': 'https://i.ytimg.com/vi/DAjyGi19mQw/hqdefault.jpg',
#   'title': 'Django 2: Sangre De Mi Sangre _ Película Peruana en español latino // el placer de los ojos.',
#   'url': 'https://www.youtube.com/watch?v=DAjyGi19mQw'},
#  {'id': '23EJTCJ28Vc',
#   'thumbnails': 'https://i.ytimg.com/vi/23EJTCJ28Vc/hqdefault.jpg',
#   'title': 'Django 1: La Otra Cara _ Película Peruana en español latino // el placer de los ojos.',
#   'url': 'https://www.youtube.com/watch?v=23EJTCJ28Vc'},
#  {'id': '1WJTXIwgV34',
#   'thumbnails': 'https://i.ytimg.com/vi/1WJTXIwgV34/hqdefault.jpg',
#   'title': 'QuickGrader (Django + React, Machine Learning)',
#   'url': 'https://www.youtube.com/watch?v=1WJTXIwgV34'},
#  {'id': 'FeCkY1g9aQQ',
#   'thumbnails': 'https://i.ytimg.com/vi/FeCkY1g9aQQ/hqdefault.jpg',
#   'title': 'Django - Zuhause gesucht',
#   'url': 'https://www.youtube.com/watch?v=FeCkY1g9aQQ'},
#  {'id': '558S6YNKMNs',
#   'thumbnails': 'https://i.ytimg.com/vi/558S6YNKMNs/hqdefault.jpg',
#   'title': 'DJANGO - ZAP KINETO # 17 - 24.05.21',
#   'url': 'https://www.youtube.com/watch?v=558S6YNKMNs'},
#  {'id': 'Qo6aXM82wTc',
#   'thumbnails': 'https://i.ytimg.com/vi/Qo6aXM82wTc/hqdefault.jpg',
#   'title': '🔥 Дешёвый Виртуальный Сервер ✅ хостинг django',
#   'url': 'https://www.youtube.com/watch?v=Qo6aXM82wTc'},
#  {'id': 'KuLQ_FlYEtY',
#   'thumbnails': 'https://i.ytimg.com/vi/KuLQ_FlYEtY/hqdefault.jpg',
#   'title': 'Lyrics Manal - DJANGO [الكلمات]',
#   'url': 'https://www.youtube.com/watch?v=KuLQ_FlYEtY'},
#  {'id': 'CE1-6J6PId8',
#   'thumbnails': 'https://i.ytimg.com/vi/CE1-6J6PId8/hqdefault.jpg',
#   'title': 'Irene&#39;s GJ Adventures 847: Mathias Berry and Antoine Angers at Django A Gogo',
#   'url': 'https://www.youtube.com/watch?v=CE1-6J6PId8'},
#  {'id': 'VJ0eHYTF0UU',
#   'thumbnails': 'https://i.ytimg.com/vi/VJ0eHYTF0UU/hqdefault.jpg',
#   'title': 'Leonardo DiCaprio Viral Scene in DJANGO UNCHAINED (2012) #Shorts',
#   'url': 'https://www.youtube.com/watch?v=VJ0eHYTF0UU'},
#  {'id': 'ggz8wkjljaM',
#   'thumbnails': 'https://i.ytimg.com/vi/ggz8wkjljaM/hqdefault.jpg',
#   'title': 'How To Generate CSV Spreadsheet Files Dynamically With Django - Django Wednesdays #16',
#   'url': 'https://www.youtube.com/watch?v=ggz8wkjljaM'},
#  {'id': 'VATeTw5C4kY',
#   'thumbnails': 'https://i.ytimg.com/vi/VATeTw5C4kY/hqdefault.jpg',
#   'title': 'Little house (Amanda Seyfried) + Freedom (Django Unchained soundtrack) | Live cover',
#   'url': 'https://www.youtube.com/watch?v=VATeTw5C4kY'},
#  {'id': 'rdO8sbL_qNE',
#   'thumbnails': 'https://i.ytimg.com/vi/rdO8sbL_qNE/hqdefault.jpg',
#   'title': 'Solo de Django Reinhardt en Nuages',
#   'url': 'https://www.youtube.com/watch?v=rdO8sbL_qNE'},
#  {'id': 'Ye8yucO1UQY',
#   'thumbnails': 'https://i.ytimg.com/vi/Ye8yucO1UQY/hqdefault.jpg',
#   'title': 'Ajax + Django (CRUD)',
#   'url': 'https://www.youtube.com/watch?v=Ye8yucO1UQY'},
#  {'id': 'v5UqEn-Cx7g',
#   'thumbnails': 'https://i.ytimg.com/vi/v5UqEn-Cx7g/hqdefault.jpg',
#   'title': 'American React To British Rap... Django x 30 x Dizz - Want Me Cuffs (Music Video) Mixtape Madmess',
#   'url': 'https://www.youtube.com/watch?v=v5UqEn-Cx7g'},
#  {'id': 'ZL9a5wqcyuQ',
#   'thumbnails': 'https://i.ytimg.com/vi/ZL9a5wqcyuQ/hqdefault.jpg',
#   'title': 'Manal - Django (With Lyrics) | منال - دجانغو (بالكلمات)',
#   'url': 'https://www.youtube.com/watch?v=ZL9a5wqcyuQ'},
#  {'id': '6CaCjfmt3z4',
#   'thumbnails': 'https://i.ytimg.com/vi/6CaCjfmt3z4/hqdefault.jpg',
#   'title': 'Programming Django Rest Api Auth Under 50 Mins',
#   'url': 'https://www.youtube.com/watch?v=6CaCjfmt3z4'},
#  {'id': 'f7J6_idBuNU',
#   'thumbnails': 'https://i.ytimg.com/vi/f7J6_idBuNU/hqdefault.jpg',
#   'title': 'Django - LCQS (PAROLES)',
#   'url': 'https://www.youtube.com/watch?v=f7J6_idBuNU'},
#  {'id': 'F3PGNPwE8EA',
#   'thumbnails': 'https://i.ytimg.com/vi/F3PGNPwE8EA/hqdefault.jpg',
#   'title': 'Django Compilation',
#   'url': 'https://www.youtube.com/watch?v=F3PGNPwE8EA'},
#  {'id': '48sxBIEwNDw',
#   'thumbnails': 'https://i.ytimg.com/vi/48sxBIEwNDw/hqdefault.jpg',
#   'title': 'Video of adoptable pet named Django',
#   'url': 'https://www.youtube.com/watch?v=48sxBIEwNDw'},
#  {'id': '82M_yuQ3CAY',
#   'thumbnails': 'https://i.ytimg.com/vi/82M_yuQ3CAY/hqdefault.jpg',
#   'title': 'Django #4 - chargement template',
#   'url': 'https://www.youtube.com/watch?v=82M_yuQ3CAY'},
#  {'id': 'YvX9OSlf4SA',
#   'thumbnails': 'https://i.ytimg.com/vi/YvX9OSlf4SA/hqdefault.jpg',
#   'title': 'جانجو 455 برمجة ارسال عرض سلة المشتريات بايثون python django جانجو',
#   'url': 'https://www.youtube.com/watch?v=YvX9OSlf4SA'},
#  {'id': 'LRpnmpClG7U',
#   'thumbnails': 'https://i.ytimg.com/vi/LRpnmpClG7U/hqdefault.jpg',
#   'title': 'Stevie Lee - PEDIGREE Ft. Django',
#   'url': 'https://www.youtube.com/watch?v=LRpnmpClG7U'},
#  {'id': '7itTZhlFLpI',
#   'thumbnails': 'https://i.ytimg.com/vi/7itTZhlFLpI/hqdefault.jpg',
#   'title': 'Manal - Django ( officiel audio ) #album360',
#   'url': 'https://www.youtube.com/watch?v=7itTZhlFLpI'},
#  {'id': 'dcqsFMKhHs0',
#   'thumbnails': 'https://i.ytimg.com/vi/dcqsFMKhHs0/hqdefault.jpg',
#   'title': 'Manal - Django ( officiel audio ) #album360',
#   'url': 'https://www.youtube.com/watch?v=dcqsFMKhHs0'},
#  {'id': 'HKYNgW6egqE',
#   'thumbnails': 'https://i.ytimg.com/vi/HKYNgW6egqE/hqdefault.jpg',
#   'title': 'Getting Products #17 | E-commerce Website | Python Django Tutorial In Hindi',
#   'url': 'https://www.youtube.com/watch?v=HKYNgW6egqE'},
#  {'id': 'XzG0DnNTPhY',
#   'thumbnails': 'https://i.ytimg.com/vi/XzG0DnNTPhY/hqdefault.jpg',
#   'title': 'Serving HTML Files #16 | E-commerce Website | Python Django Tutorial In Hindi',
#   'url': 'https://www.youtube.com/watch?v=XzG0DnNTPhY'},
#  {'id': '7_h1ndIb4Rk',
#   'thumbnails': 'https://i.ytimg.com/vi/7_h1ndIb4Rk/hqdefault.jpg',
#   'title': 'API view Django Rest framework | Django rest framework tutorial',
#   'url': 'https://www.youtube.com/watch?v=7_h1ndIb4Rk'},
#  {'id': 'WNwwOam-B1s',
#   'thumbnails': 'https://i.ytimg.com/vi/WNwwOam-B1s/hqdefault.jpg',
#   'title': 'Nestest Serializers django rest framework| Serializers in django rest framework | [ Rest framework]',
#   'url': 'https://www.youtube.com/watch?v=WNwwOam-B1s'},
#  {'id': 'GPgbStF71es',
#   'thumbnails': 'https://i.ytimg.com/vi/GPgbStF71es/hqdefault.jpg',
#   'title': 'Django Class 2',
#   'url': 'https://www.youtube.com/watch?v=GPgbStF71es'},
#  {'id': 'GaqWiYWV2Rc',
#   'thumbnails': 'https://i.ytimg.com/vi/GaqWiYWV2Rc/hqdefault.jpg',
#   'title': 'Sales &amp; Marketing Management System | Django Python',
#   'url': 'https://www.youtube.com/watch?v=GaqWiYWV2Rc'},
#  {'id': 'Z8Xrs5MfcZQ',
#   'thumbnails': 'https://i.ytimg.com/vi/Z8Xrs5MfcZQ/hqdefault.jpg',
#   'title': 'Lip Sync Django',
#   'url': 'https://www.youtube.com/watch?v=Z8Xrs5MfcZQ'},
#  {'id': 'OSJhEnLvE3Q',
#   'thumbnails': 'https://i.ytimg.com/vi/OSJhEnLvE3Q/hqdefault.jpg',
#   'title': 'Django Setup and Basics (Tamil) | Django Tutorial in Tamil',
#   'url': 'https://www.youtube.com/watch?v=OSJhEnLvE3Q'},
#  {'id': 'DEtDTuoMhL8',
#   'thumbnails': 'https://i.ytimg.com/vi/DEtDTuoMhL8/hqdefault.jpg',
#   'title': 'permission errors with python/django',
#   'url': 'https://www.youtube.com/watch?v=DEtDTuoMhL8'},
#  {'id': '-wpkr38QU2k',
#   'thumbnails': 'https://i.ytimg.com/vi/-wpkr38QU2k/hqdefault.jpg',
#   'title': 'Learn free python Course  ||  Python Django (Media File Setting &amp; Models Creation)',
#   'url': 'https://www.youtube.com/watch?v=-wpkr38QU2k'},
#  {'id': 'E0yMcf5ezZM',
#   'thumbnails': 'https://i.ytimg.com/vi/E0yMcf5ezZM/hqdefault.jpg',
#   'title': 'l&#39;artiste Django',
#   'url': 'https://www.youtube.com/watch?v=E0yMcf5ezZM'},
#  {'id': 'Am1KzD0cTNk',
#   'thumbnails': 'https://i.ytimg.com/vi/Am1KzD0cTNk/hqdefault.jpg',
#   'title': 'l&#39;artiste Django',
#   'url': 'https://www.youtube.com/watch?v=Am1KzD0cTNk'},
#  {'id': 'wVhncZ2FTYA',
#   'thumbnails': 'https://i.ytimg.com/vi/wVhncZ2FTYA/hqdefault.jpg',
#   'title': 'Python Django Video Class || Sending Email On User Registration In django',
#   'url': 'https://www.youtube.com/watch?v=wVhncZ2FTYA'},
#  {'id': 'n7mU-3phLE4',
#   'thumbnails': 'https://i.ytimg.com/vi/n7mU-3phLE4/hqdefault.jpg',
#   'title': 'DJ Django * Bush Master',
#   'url': 'https://www.youtube.com/watch?v=n7mU-3phLE4'},
#  {'id': '8sGoMrDczeg',
#   'thumbnails': 'https://i.ytimg.com/vi/8sGoMrDczeg/hqdefault.jpg',
#   'title': 'Python django tutorial for 2020',
#   'url': 'https://www.youtube.com/watch?v=8sGoMrDczeg'},
#  {'id': 'KLsJjfCOiQA',
#   'thumbnails': 'https://i.ytimg.com/vi/KLsJjfCOiQA/hqdefault.jpg',
#   'title': 'Recado Bossa Nova (D. Ferreira et L. Antonio) -  Autour de Django (2021)',
#   'url': 'https://www.youtube.com/watch?v=KLsJjfCOiQA'},
#  {'id': 'ihBXSSqU80g',
#   'thumbnails': 'https://i.ytimg.com/vi/ihBXSSqU80g/hqdefault.jpg',
#   'title': 'Las Aventuras de Django .AMOR y HONOR',
#   'url': 'https://www.youtube.com/watch?v=ihBXSSqU80g'},
#  {'id': '_OhW3LS73uw',
#   'thumbnails': 'https://i.ytimg.com/vi/_OhW3LS73uw/hqdefault.jpg',
#   'title': 'Ma che bello questo Amore E. RAMAZZOTTI (Enzo Django Covers) 21/05',
#   'url': 'https://www.youtube.com/watch?v=_OhW3LS73uw'},
#  {'id': 'MRSQFDui0ac',
#   'thumbnails': 'https://i.ytimg.com/vi/MRSQFDui0ac/hqdefault.jpg',
#   'title': 'How to Host Django Website on AWS | How to Deploy Django Website | Easiest Way!! - Part 1',
#   'url': 'https://www.youtube.com/watch?v=MRSQFDui0ac'},
#  {'id': 'elyK9-kDG7g',
#   'thumbnails': 'https://i.ytimg.com/vi/elyK9-kDG7g/hqdefault.jpg',
#   'title': 'Movie Recommender System using Django, Vuejs, TMDB API',
#   'url': 'https://www.youtube.com/watch?v=elyK9-kDG7g'},
#  {'id': '98EIZCf211U',
#   'thumbnails': 'https://i.ytimg.com/vi/98EIZCf211U/hqdefault.jpg',
#   'title': 'THE DJANGO ORCHESTRA - Impromptu (Live)',
#   'url': 'https://www.youtube.com/watch?v=98EIZCf211U'},
#  {'id': '0OfLZefC478',
#   'thumbnails': 'https://i.ytimg.com/vi/0OfLZefC478/hqdefault.jpg',
#   'title': 'How To Make E-commerce Website Using Python Django | Django | Hindi | Django Tutorial In Hindi 🤨',
#   'url': 'https://www.youtube.com/watch?v=0OfLZefC478'},
#  {'id': 'XQ7pD5b5mmY',
#   'thumbnails': 'https://i.ytimg.com/vi/XQ7pD5b5mmY/hqdefault.jpg',
#   'title': 'Django için HTML Template Ayırma  5',
#   'url': 'https://www.youtube.com/watch?v=XQ7pD5b5mmY'},
#  {'id': 'qnftV6TwyX0',
#   'thumbnails': 'https://i.ytimg.com/vi/qnftV6TwyX0/hqdefault.jpg',
#   'title': 'Calito  Django',
#   'url': 'https://www.youtube.com/watch?v=qnftV6TwyX0'},
#  {'id': 'LdVU5Y-o0OA',
#   'thumbnails': 'https://i.ytimg.com/vi/LdVU5Y-o0OA/hqdefault.jpg',
#   'title': 'Django Jet - Stomping at Decca - Šelepka Live 2019',
#   'url': 'https://www.youtube.com/watch?v=LdVU5Y-o0OA'},
#  {'id': '-o_3zNXrQ-s',
#   'thumbnails': 'https://i.ytimg.com/vi/-o_3zNXrQ-s/hqdefault.jpg',
#   'title': 'Django için HTML Template Ayırma  4',
#   'url': 'https://www.youtube.com/watch?v=-o_3zNXrQ-s'},
#  {'id': 'xLjOJHJ7cQo',
#   'thumbnails': 'https://i.ytimg.com/vi/xLjOJHJ7cQo/hqdefault.jpg',
#   'title': 'Django 1966 But Instead It&#39;s Terrence Hill',
#   'url': 'https://www.youtube.com/watch?v=xLjOJHJ7cQo'},
#  {'id': 'UZZAXc_vClA',
#   'thumbnails': 'https://i.ytimg.com/vi/UZZAXc_vClA/hqdefault.jpg',
#   'title': 'Building a reusable app in Django 3.2 - Part 4',
#   'url': 'https://www.youtube.com/watch?v=UZZAXc_vClA'},
#  {'id': 'x4cE_DmRGk4',
#   'thumbnails': 'https://i.ytimg.com/vi/x4cE_DmRGk4/hqdefault.jpg',
#   'title': '#4 | Templates Rendering | Django Tutorials | Python Web Framework | Django 💻',
#   'url': 'https://www.youtube.com/watch?v=x4cE_DmRGk4'},
#  {'id': 'tusnO1u7kJ4',
#   'thumbnails': 'https://i.ytimg.com/vi/tusnO1u7kJ4/hqdefault.jpg',
#   'title': 'DJANGO tutorials || Demo - 4 || by Mr. Wilson On 26-05-2021 @10AM IST',
#   'url': 'https://www.youtube.com/watch?v=tusnO1u7kJ4'},
#  {'id': 'i6KVYqrxm4A',
#   'thumbnails': 'https://i.ytimg.com/vi/i6KVYqrxm4A/hqdefault.jpg',
#   'title': 'Django için HTML Template Ayırma  3',
#   'url': 'https://www.youtube.com/watch?v=i6KVYqrxm4A'}]
